# %% [markdown]
# <a href="https://colab.research.google.com/github/naveelnaveel30-source/dynamic-portfolio/blob/main/trascribesece.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('welcome in google colab')
# Out:
# welcome in google colab
